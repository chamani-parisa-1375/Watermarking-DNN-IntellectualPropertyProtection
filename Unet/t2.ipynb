# %%
import cv2
image_path = rf'datasets\flood_area_segmnet\test\test_0.jpg'

image = cv2.resize(cv2.imread(image_path),(512,256))

img = image[:,:256]
mask = image[:,256:]

cv2.imwrite(rf'datasets\flood_area_segmnet\test_image.jpg',img)
cv2.imwrite(rf'datasets\flood_area_segmnet\test_mask.jpg',mask)
# Out:
# True
